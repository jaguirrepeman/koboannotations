# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import sys
import os

# Añadir el directorio raíz del proyecto al path
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from src.db_manager import SQLiteWrapper
from src.transfer_annotations import transfer_all_annotations

pd.options.display.max_columns = None

# %% [markdown]
# ## 1. Configuración de Bases de Datos
#
# Especifica las rutas a tus bases de datos origen (antigua) y destino (nueva).

# %%
# Base de datos ANTIGUA (origen de las anotaciones)
db_path_old = os.path.join("..", "data", "KoboReader.sqlite")

# Base de datos NUEVA (destino de las anotaciones)
db_path_new = os.path.join("..", "data", "KoboReader_5ene.sqlite")

# Conectar a ambas bases de datos
db_old = SQLiteWrapper(db_path_old)
db_old.connect()

db_new = SQLiteWrapper(db_path_new)
db_new.connect()

print(f"✅ Conectado a BD antigua: {db_path_old}")
print(f"✅ Conectado a BD nueva: {db_path_new}")
# Out:
# ✅ Conectado a BD antigua: ..\data\KoboReader.sqlite
# ✅ Conectado a BD nueva: ..\data\KoboReader_5ene.sqlite

# %% [markdown]
# ## 2. Opción A: Transferir un libro específico
#
# Útil cuando has redescargado un solo libro o unos pocos libros.

# %%
# Transferir un libro específico usando transfer_all_annotations con filtro
# Cambiar el título exacto del libro que necesites

book_title = "Una historia de España"  # Título EXACTO del libro

# Primero simular (dry_run=True)
stats = transfer_all_annotations(
    source_db_path=db_path_old,
    target_db_path=db_path_new,
    dry_run=True,  # Cambiar a False para ejecutar realmente
    book_filter=[book_title]  # Lista con el/los libro(s) específico(s)
)

print("\n" + "="*80)
print("💡 Si todo se ve correcto, cambia dry_run=False y ejecuta de nuevo")
print("="*80)

# %% [markdown]
# ## 3. Opción B: Transferir todos los libros automáticamente
#
# Transfiere todos los libros que tienen anotaciones en la BD antigua pero no en la nueva.
#
# **⚠️ IMPORTANTE**: Siempre ejecuta primero con `dry_run=True` para ver qué se va a transferir.

# %%
# Transferencia masiva de todos los libros

stats = transfer_all_annotations(
    source_db_path=db_path_old,
    target_db_path=db_path_new,
    dry_run=False,  # ⚠️ Cambiar a False para ejecutar realmente
    # dry_run=True,  # ⚠️ Cambiar a False para ejecutar realmente
    book_filter=None  # O especificar: ["Libro 1", "Libro 2"]
    # book_filter= [
    #     "The Slight Edge: Turning Simple Disciplines into Massive Success and Happiness",
    #     "Una historia de España"
    #     ]
  # O especificar: ["Libro 1", "Libro 2"]
)

print("\n" + "="*80)
print("💡 Si todo se ve correcto, cambia dry_run=False y ejecuta de nuevo")
print("="*80)
# Out:
# ================================================================================
# TRANSFERENCIA MASIVA DE ANOTACIONES
# Modo: ⚠️ EJECUCIÓN REAL
# ================================================================================
#
# Origen: ..\data\KoboReader.sqlite
# Destino: ..\data\KoboReader_5ene.sqlite
#
# 📚 Libros con anotaciones en BD origen: 52
# 📗 Libros con anotaciones en BD destino: 29
#
# ================================================================================
# PROCESANDO LIBROS
# ================================================================================
#
# [1/52] 12 reglas para vivir
#    Autor: Jordan Peterson
#    Anotaciones: 12
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [2/52] 1984
#    Autor: George Orwell
#    Anotaciones: 2
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [3/52] A puerta cerrada
#    Autor: J. D. Barker
#    Anotaciones: 1
#
# 📚 Libros con anotaciones en BD origen: 52
# 📗 Libros con anotaciones en BD destino: 29
#
# ================================================================================
# PROCESANDO LIBROS
# ================================================================================
#
# [1/52] 12 reglas para vivir
#    Autor: Jordan Peterson
#    Anotaciones: 12
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [2/52] 1984
#    Autor: George Orwell
#    Anotaciones: 2
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [3/52] A puerta cerrada
#    Autor: J. D. Barker
#    Anotaciones: 1
#    ✅ TRANSFERIDO: 1 anotaciones
#
# [4/52] Acontece que no es poco
#    Autor: Nieves Concostrina
#    Anotaciones: 4
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [5/52] Amanecer
#    Autor: Conn Iggulden
#    Anotaciones: 4
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [6/52] Attached: Are you Anxious, Avoidant or Secure? How the science of adult attachment can help you find – and keep – love
#    Autor: Levine, Amir
#    Anotaciones: 150
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [7/52] Autopsicología. Ejercicios y claves para una buena salud mental
#    Autor: Alberto Bermejo Mercader
#    Anotaciones: 125
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [8/52] Breaking the Habit of Being Yourself
#    Autor: Joe Dispenza
#    Anotaciones: 61
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [9/52] Charisma on Command: Inspire, Impress, and Energize Everyone You Meet
#    Autor: Charlie Houpert
#    Anotaciones: 179
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [10/52] Como hacer que te pasen cosas buenas
#    Autor: Marian Rojas Estapé
#    Anotaciones: 35
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [11/52] Cómo analizar a las personas y el lenguaje corporal
#    Autor: Chase Hill
#    Anotaciones: 155
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [12/52] Cómo invertir en Bolsa a largo plazo partiendo de cero
#    Autor: Gregorio Hernández Jiménez
#    Anotaciones: 61
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [13/52] Cómo invertir en fondos de inversión con sentido común
#    Autor: John C. Bogle
#    Anotaciones: 33
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [14/52] Cómo piensan los ricos
#    Autor: Morgan Housel
#    Anotaciones: 67
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [15/52] Educación financiera avanzada partiendo de cero
#    Autor: Gregorio Hernández Jiménez
#    Anotaciones: 59
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [16/52] El arte de amar
#    Autor: Erich Fromm
#    Anotaciones: 144
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [17/52] El hombre en busca de sentido
#    Autor: Viktor Frankl
#    Anotaciones: 28
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [18/52] El lobo de Wall Street
#    Autor: Jordan Belfort
#    Anotaciones: 1
#    ✅ TRANSFERIDO: 1 anotaciones
#
# [19/52] El poder de confiar en ti mismo
#    Autor: Brian Tracy
#    Anotaciones: 63
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [20/52] El sutil arte de que (casi todo) te importe una mierda
#    Autor: Mark Manson
#    Anotaciones: 80
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [21/52] El universo de lo sencillo
#    Autor: Pablo Arribas
#    Anotaciones: 37
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [22/52] Encuentra tu persona vitamina
#    Autor: Marian Rojas Estapé
#    Anotaciones: 50
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [23/52] ES MANIPULACIÓN Y NO LO SABES: DESACTIVA LAS TRAMPAS EMOCIONALES EN TODOS LOS ÁMBITOS DE TU VIDA
#    Autor: Claudia Nicolasa
#    Anotaciones: 443
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [24/52] Feel-Good Productivity
#    Autor: Ali Abdaal
#    Anotaciones: 18
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [25/52] Fluir (Flow)
#    Autor: Mihály Csíkszentmihályi
#    Anotaciones: 178
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [26/52] Google Cloud Certified Professional Cloud Architect Study Guide
#    Autor: Dan Sullivan
#    Anotaciones: 1
#    ✅ TRANSFERIDO: 1 anotaciones
#
# [27/52] Grit
#    Autor: Angela Duckworth
#    Anotaciones: 70
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [28/52] Hablar con extraños
#    Autor: Malcolm Gladwell
#    Anotaciones: 41
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [29/52] How To
#    Autor: Phil Chambers
#    Anotaciones: 39
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [30/52] How to Win at Chess
#    Autor: Levy Rozman
#    Anotaciones: 1
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [31/52] Independízate de Papá Estado
#    Autor: Carlos Galán Rubio
#    Anotaciones: 20
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [32/52] Juana de Arco
#    Autor: Mark Twain
#    Anotaciones: 2
#    ✅ TRANSFERIDO: 1 anotaciones
#
# [4/52] Acontece que no es poco
#    Autor: Nieves Concostrina
#    Anotaciones: 4
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [5/52] Amanecer
#    Autor: Conn Iggulden
#    Anotaciones: 4
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [6/52] Attached: Are you Anxious, Avoidant or Secure? How the science of adult attachment can help you find – and keep – love
#    Autor: Levine, Amir
#    Anotaciones: 150
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [7/52] Autopsicología. Ejercicios y claves para una buena salud mental
#    Autor: Alberto Bermejo Mercader
#    Anotaciones: 125
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [8/52] Breaking the Habit of Being Yourself
#    Autor: Joe Dispenza
#    Anotaciones: 61
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [9/52] Charisma on Command: Inspire, Impress, and Energize Everyone You Meet
#    Autor: Charlie Houpert
#    Anotaciones: 179
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [10/52] Como hacer que te pasen cosas buenas
#    Autor: Marian Rojas Estapé
#    Anotaciones: 35
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [11/52] Cómo analizar a las personas y el lenguaje corporal
#    Autor: Chase Hill
#    Anotaciones: 155
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [12/52] Cómo invertir en Bolsa a largo plazo partiendo de cero
#    Autor: Gregorio Hernández Jiménez
#    Anotaciones: 61
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [13/52] Cómo invertir en fondos de inversión con sentido común
#    Autor: John C. Bogle
#    Anotaciones: 33
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [14/52] Cómo piensan los ricos
#    Autor: Morgan Housel
#    Anotaciones: 67
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [15/52] Educación financiera avanzada partiendo de cero
#    Autor: Gregorio Hernández Jiménez
#    Anotaciones: 59
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [16/52] El arte de amar
#    Autor: Erich Fromm
#    Anotaciones: 144
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [17/52] El hombre en busca de sentido
#    Autor: Viktor Frankl
#    Anotaciones: 28
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [18/52] El lobo de Wall Street
#    Autor: Jordan Belfort
#    Anotaciones: 1
#    ✅ TRANSFERIDO: 1 anotaciones
#
# [19/52] El poder de confiar en ti mismo
#    Autor: Brian Tracy
#    Anotaciones: 63
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [20/52] El sutil arte de que (casi todo) te importe una mierda
#    Autor: Mark Manson
#    Anotaciones: 80
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [21/52] El universo de lo sencillo
#    Autor: Pablo Arribas
#    Anotaciones: 37
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [22/52] Encuentra tu persona vitamina
#    Autor: Marian Rojas Estapé
#    Anotaciones: 50
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [23/52] ES MANIPULACIÓN Y NO LO SABES: DESACTIVA LAS TRAMPAS EMOCIONALES EN TODOS LOS ÁMBITOS DE TU VIDA
#    Autor: Claudia Nicolasa
#    Anotaciones: 443
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [24/52] Feel-Good Productivity
#    Autor: Ali Abdaal
#    Anotaciones: 18
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [25/52] Fluir (Flow)
#    Autor: Mihály Csíkszentmihályi
#    Anotaciones: 178
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [26/52] Google Cloud Certified Professional Cloud Architect Study Guide
#    Autor: Dan Sullivan
#    Anotaciones: 1
#    ✅ TRANSFERIDO: 1 anotaciones
#
# [27/52] Grit
#    Autor: Angela Duckworth
#    Anotaciones: 70
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [28/52] Hablar con extraños
#    Autor: Malcolm Gladwell
#    Anotaciones: 41
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [29/52] How To
#    Autor: Phil Chambers
#    Anotaciones: 39
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [30/52] How to Win at Chess
#    Autor: Levy Rozman
#    Anotaciones: 1
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [31/52] Independízate de Papá Estado
#    Autor: Carlos Galán Rubio
#    Anotaciones: 20
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [32/52] Juana de Arco
#    Autor: Mark Twain
#    Anotaciones: 2
#    ✅ TRANSFERIDO: 2 anotaciones
#
# [33/52] La ciudad de los prodigios
#    Autor: Eduardo Mendoza
#    Anotaciones: 2
#    ✅ TRANSFERIDO: 2 anotaciones
#
# [34/52] LA TIMIDEZ
#    Autor: CHRISTOPHE ANDRE
#    Anotaciones: 21
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [35/52] Las 5 trampas del amor
#    Autor: Iñaki Piñuel
#    Anotaciones: 92
#    ✅ TRANSFERIDO: 2 anotaciones
#
# [33/52] La ciudad de los prodigios
#    Autor: Eduardo Mendoza
#    Anotaciones: 2
#    ✅ TRANSFERIDO: 2 anotaciones
#
# [34/52] LA TIMIDEZ
#    Autor: CHRISTOPHE ANDRE
#    Anotaciones: 21
#    ⏭️  OMITIDO: Ya existen anotaciones en BD destino
#
# [35/52] Las 5 trampas del amor
#    Autor: Iñaki Piñuel
#    Anotaciones: 92
#    ✅ TRANSFERIDO: 92 anotaciones
#
# [36/52] Las madres
#    Autor: Carmen Mola
#    Anotaciones: 1
#    ✅ TRANSFERIDO: 1 anotaciones
#
# [37/52] Los dones de la imperfección
#    Autor: Brené Brown
#    Anotaciones: 76
#    ✅ TRANSFERIDO: 92 anotaciones
#
# [36/52] Las madres
#    Autor: Carmen Mola
#    Anotaciones: 1
#    ✅ TRANSFERIDO: 1 anotaciones
#
# [37/52] Los dones de la imperfección
#    Autor: Brené Brown
#    Anotaciones: 76
#    ✅ TRANSFERIDO: 76 anotaciones
#
# [38/52] Los seis pilares de la autoestima
#    Autor: Nathaniel Branden
#    Anotaciones: 14
#    ✅ TRANSFERIDO: 76 anotaciones
#
# [38/52] Los seis pilares de la autoestima
#    Autor: Nathaniel Branden
#    Anotaciones: 14
#    ✅ TRANSFERIDO: 14 anotaciones
#
# [39/52] Manipulación y psicología oscura
#    Autor: Alejandro Mendoza
#    Anotaciones: 7
#    ✅ TRANSFERIDO: 7 anotaciones
#
# [40/52] Mindset
#    Autor: Carol S. Dweck
#    Anotaciones: 79
#    ✅ TRANSFERIDO: 14 anotaciones
#
# [39/52] Manipulación y psicología oscura
#    Autor: Alejandro Mendoza
#    Anotaciones: 7
#    ✅ TRANSFERIDO: 7 anotaciones
#
# [40/52] Mindset
#    Autor: Carol S. Dweck
#    Anotaciones: 79
#    ✅ TRANSFERIDO: 79 anotaciones
#
# [41/52] Minimalismo digital
#    Autor: Cal Newport
#    Anotaciones: 26
#    ✅ TRANSFERIDO: 79 anotaciones
#
# [41/52] Minimalismo digital
#    Autor: Cal Newport
#    Anotaciones: 26
#    ✅ TRANSFERIDO: 26 anotaciones
#
# [42/52] Models
#    Autor: Mark Manson
#    Anotaciones: 154
#    ✅ TRANSFERIDO: 26 anotaciones
#
# [42/52] Models
#    Autor: Mark Manson
#    Anotaciones: 154
#    ✅ TRANSFERIDO: 154 anotaciones
#
# [43/52] No More Mr. Nice Guy
#    Autor: Robert A. Glover
#    Anotaciones: 72
#    ✅ TRANSFERIDO: 154 anotaciones
#
# [43/52] No More Mr. Nice Guy
#    Autor: Robert A. Glover
#    Anotaciones: 72
#    ✅ TRANSFERIDO: 72 anotaciones
#
# [44/52] Once anillos
#    Autor: Phil Jackson
#    Anotaciones: 1
#    ✅ TRANSFERIDO: 1 anotaciones
#
# [45/52] Psicología oscura
#    Autor: Pietro Moretti
#    Anotaciones: 11
#    ✅ TRANSFERIDO: 72 anotaciones
#
# [44/52] Once anillos
#    Autor: Phil Jackson
#    Anotaciones: 1
#    ✅ TRANSFERIDO: 1 anotaciones
#
# [45/52] Psicología oscura
#    Autor: Pietro Moretti
#    Anotaciones: 11
#    ✅ TRANSFERIDO: 11 anotaciones
#
# [46/52] Salir del infierno
#    Autor: Iñaki Piñuel
#    Anotaciones: 41
#    ✅ TRANSFERIDO: 11 anotaciones
#
# [46/52] Salir del infierno
#    Autor: Iñaki Piñuel
#    Anotaciones: 41
#    ✅ TRANSFERIDO: 41 anotaciones
#
# [47/52] Surrounded by Idiots
#    Autor: Thomas Erikson
#    Anotaciones: 158
# Error ejecutando la consulta: Execution failed on sql '
#         SELECT COUNT(*) as total
#         FROM Bookmark
#         WHERE VolumeID = 'file:///mnt/onboard/.kobo/dropbox/Surrounded by idiots_ the four types of human behavior and -- Bradbury, Rod;Erikson, Thomas;Pender, Martin -- St_ Martin's Essentials, First Edition, -- 9781250179944 -- d5276a97a2db0fa3010cac81bdeb6ac3 -- Anna’s Archive.epub'
#         AND Type IN ('highlight', 'note')
#     ': near "s": syntax error
#    ✅ TRANSFERIDO: 41 anotaciones
#
# [47/52] Surrounded by Idiots
#    Autor: Thomas Erikson
#    Anotaciones: 158
# Error ejecutando la consulta: Execution failed on sql '
#         SELECT COUNT(*) as total
#         FROM Bookmark
#         WHERE VolumeID = 'file:///mnt/onboard/.kobo/dropbox/Surrounded by idiots_ the four types of human behavior and -- Bradbury, Rod;Erikson, Thomas;Pender, Martin -- St_ Martin's Essentials, First Edition, -- 9781250179944 -- d5276a97a2db0fa3010cac81bdeb6ac3 -- Anna’s Archive.epub'
#         AND Type IN ('highlight', 'note')
#     ': near "s": syntax error
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\sql.py:2674, in SQLiteDatabase.execute(self, sql, params)
#    2673 try:
# -> 2674     cur.execute(sql, *args)
#    2675     return cur
#
# OperationalError: near "s": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# Cell In[5], line 3
#       1 # Transferencia masiva de todos los libros
# ----> 3 stats = transfer_all_annotations(
#       4     source_db_path=db_path_old,
#       5     target_db_path=db_path_new,
#       6     dry_run=False,  # ⚠️ Cambiar a False para ejecutar realmente
#       7     # dry_run=True,  # ⚠️ Cambiar a False para ejecutar realmente
#       8     book_filter=None  # O especificar: ["Libro 1", "Libro 2"]
#       9     # book_filter= [
#      10     #     "The Slight Edge: Turning Simple Disciplines into Massive Success and Happiness",
#      11     #     "Una historia de España"
#      12     #     ]
#      13   # O especificar: ["Libro 1", "Libro 2"]
#      14 )
#      16 print("\n" + "="*80)
#      17 print("💡 Si todo se ve correcto, cambia dry_run=False y ejecuta de nuevo")
#
# File c:\Users\jaguirrepeman\OneDrive - Deloitte (O365D)\Documents\DS\KOBO\koboannotations\src\transfer_annotations.py:278, in transfer_all_annotations(source_db_path, target_db_path, dry_run, book_filter)
#     275     continue
#     277 # Transferir
# --> 278 result = transfer_book_annotations(
#     279     db_source, db_target, volume_id, book_title, dry_run
#     280 )
#     282 global_stats['processed'] += 1
#     284 if result['status'] == 'success':
#
# File c:\Users\jaguirrepeman\OneDrive - Deloitte (O365D)\Documents\DS\KOBO\koboannotations\src\transfer_annotations.py:82, in transfer_book_annotations(db_source, db_target, volume_id_old, book_title, dry_run)
#      79 volume_id_new = book_new['ContentID'].iloc[0]
#      81 # 2. Verificar si ya existen anotaciones en la BD nueva
# ---> 82 existing_annotations = db_target.get_query_df(f"""
#      83     SELECT COUNT(*) as total
#      84     FROM Bookmark
#      85     WHERE VolumeID = '{volume_id_new}'
#      86     AND Type IN ('highlight', 'note')
#      87 """)
#      89 if existing_annotations['total'].iloc[0] > 0:
#      90     return {
#      91         "status": "skipped",
#      92         "message": f"Ya existen {existing_annotations['total'].iloc[0]} anotaciones en BD nueva",
#      93         "transferred": 0,
#      94         "skipped": existing_annotations['total'].iloc[0]
#      95     }
#
# File c:\Users\jaguirrepeman\OneDrive - Deloitte (O365D)\Documents\DS\KOBO\koboannotations\src\db_manager.py:40, in SQLiteWrapper.get_query_df(self, query, params)
#      36     raise ValueError("Conexión no establecida. Llama a `connect()` primero.")
#      38 try:
#      39     # Ejecutar la consulta y devolver un DataFrame
# ---> 40     return pd.read_sql_query(query, self.connection, params=params)
#      41 except Exception as e:
#      42     print(f"Error ejecutando la consulta: {e}")
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\sql.py:526, in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     523 assert dtype_backend is not lib.no_default
#     525 with pandasSQL_builder(con) as pandas_sql:
# --> 526     return pandas_sql.read_query(
#     527         sql,
#     528         index_col=index_col,
#     529         params=params,
#     530         coerce_float=coerce_float,
#     531         parse_dates=parse_dates,
#     532         chunksize=chunksize,
#     533         dtype=dtype,
#     534         dtype_backend=dtype_backend,
#     535     )
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\sql.py:2738, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2727 def read_query(
#    2728     self,
#    2729     sql,
#    (...)
#    2736     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737 ) -> DataFrame | Iterator[DataFrame]:
# -> 2738     cursor = self.execute(sql, params)
#    2739     columns = [col_desc[0] for col_desc in cursor.description]
#    2741     if chunksize is not None:
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\io\sql.py:2686, in SQLiteDatabase.execute(self, sql, params)
#    2683     raise ex from inner_exc
#    2685 ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686 raise ex from exc
#
# DatabaseError: Execution failed on sql '
#         SELECT COUNT(*) as total
#         FROM Bookmark
#         WHERE VolumeID = 'file:///mnt/onboard/.kobo/dropbox/Surrounded by idiots_ the four types of human behavior and -- Bradbury, Rod;Erikson, Thomas;Pender, Martin -- St_ Martin's Essentials, First Edition, -- 9781250179944 -- d5276a97a2db0fa3010cac81bdeb6ac3 -- Anna’s Archive.epub'
#         AND Type IN ('highlight', 'note')
#     ': near "s": syntax error

# %% [markdown]
# ### ⚠️ Importante sobre el guardado
#
# El script **SÍ guarda en la base de datos** cuando `dry_run=False`, PERO:
#
# 1. **Omite libros que ya tienen anotaciones** en la BD destino (previene duplicados)
# 2. Si el output dice "OMITIDO: Ya existen anotaciones", entonces NO se transfirió nada
# 3. El commit se hace automáticamente después de transferir cada libro exitosamente
#
# **Para forzar la transferencia:**
# - Debes **borrar primero** las anotaciones existentes del libro en la BD destino
# - O usar la celda de abajo para verificar si realmente se guardaron los cambios

# %%
# Verificar si realmente se guardaron las anotaciones en la BD nueva
# Esta celda verifica el número REAL de anotaciones en el archivo físico

# Reconectar para asegurar que leemos el estado actual del archivo
db_new.close()
db_new = SQLiteWrapper(db_path_new)
db_new.connect()

# Contar anotaciones actuales
check_query = """
    SELECT 
        c.Title as Título,
        COUNT(*) as Anotaciones_Actuales
    FROM Bookmark b
    INNER JOIN content c ON b.VolumeID = c.ContentID
    WHERE b.Type IN ('highlight', 'note')
    AND c.Title IN ('Una historia de España', 'The Slight Edge: Turning Simple Disciplines into Massive Success and Happiness')
    GROUP BY c.Title
"""

current_annotations = db_new.get_query_df(check_query)
print("="*80)
print("📊 VERIFICACIÓN: Anotaciones en BD nueva (estado actual)")
print("="*80)
print(current_annotations.to_string(index=False))

print("\n💡 Si NO aparecen anotaciones:")
print("   1. Los libros fueron OMITIDOS porque ya tenían anotaciones")
print("   2. O hubo un error durante la transferencia")
print("\n💡 Si aparecen anotaciones:")
print("   ✅ La transferencia fue exitosa y se guardó en el archivo")
# Out:
# ================================================================================
# 📊 VERIFICACIÓN: Anotaciones en BD nueva (estado actual)
# ================================================================================
#                                                                         Título  Anotaciones_Actuales
# The Slight Edge: Turning Simple Disciplines into Massive Success and Happiness                    14
#                                                         Una historia de España                     3
#
# 💡 Si NO aparecen anotaciones:
#    1. Los libros fueron OMITIDOS porque ya tenían anotaciones
#    2. O hubo un error durante la transferencia
#
# 💡 Si aparecen anotaciones:
#    ✅ La transferencia fue exitosa y se guardó en el archivo

# %% [markdown]
# ## 4. Verificación: Ver libros con anotaciones
#
# Útil para identificar qué libros necesitan transferencia.

# %%
# Libros con anotaciones en BD ANTIGUA
query_old = """
    SELECT 
        c.Title as Título,
        c.Attribution as Autor,
        COUNT(*) as Anotaciones
    FROM Bookmark b
    INNER JOIN content c ON b.VolumeID = c.ContentID
    WHERE b.Type IN ('highlight', 'note')
    GROUP BY c.Title, c.Attribution
    ORDER BY Anotaciones DESC
"""

books_old = db_old.get_query_df(query_old)
print("="*80)
print(f"📚 LIBROS CON ANOTACIONES EN BD ANTIGUA: {len(books_old)}")
print("="*80)
print(books_old.head(20))
# Out:
# ================================================================================
# 📚 LIBROS CON ANOTACIONES EN BD ANTIGUA: 52
# ================================================================================
#                                                Título  \
# 0   ES MANIPULACIÓN Y NO LO SABES: DESACTIVA LAS T...
# 1                            The Happiness Hypothesis
# 2   Charisma on Command: Inspire, Impress, and Ene...
# 3                                        Fluir (Flow)
# 4                                Surrounded by Idiots
# 5   Cómo analizar a las personas y el lenguaje cor...
# 6                                              Models
# 7   Attached: Are you Anxious, Avoidant or Secure?...
# 8                                     El arte de amar
# 9   Autopsicología. Ejercicios y claves para una b...
# 10                             Las 5 trampas del amor
# 11  El sutil arte de que (casi todo) te importe un...
# 12                                            Mindset
# 13                       Los dones de la imperfección
# 14                               No More Mr. Nice Guy
# 15                                               Grit
# 16                             Cómo piensan los ricos
# 17                    El poder de confiar en ti mismo
# 18               Breaking the Habit of Being Yourself
# 19  Cómo invertir en Bolsa a largo plazo partiendo...
#
#                          Autor  Anotaciones
# 0             Claudia Nicolasa          443
# 1               Jonathan Haidt          260
# 2              Charlie Houpert          179
# 3      Mihály Csíkszentmihályi          178
# 4               Thomas Erikson          158
# 5                   Chase Hill          155
# 6                  Mark Manson          154
# 7                 Levine, Amir          150
# 8                  Erich Fromm          144
# 9     Alberto Bermejo Mercader          125
# 10                Iñaki Piñuel           92
# 11                 Mark Manson           80
# 12              Carol S. Dweck           79
# 13                 Brené Brown           76
# 14            Robert A. Glover           72
# 15            Angela Duckworth           70
# 16               Morgan Housel           67
# 17                 Brian Tracy           63
# 18                Joe Dispenza           61
# 19  Gregorio Hernández Jiménez           61

# %%
# Libros con anotaciones en BD NUEVA
query_new = """
    SELECT 
        c.Title as Título,
        c.Attribution as Autor,
        COUNT(*) as Anotaciones
    FROM Bookmark b
    INNER JOIN content c ON b.VolumeID = c.ContentID
    WHERE b.Type IN ('highlight', 'note')
    GROUP BY c.Title, c.Attribution
    ORDER BY Anotaciones DESC
"""

books_new = db_new.get_query_df(query_new)
print("="*80)
print(f"📗 LIBROS CON ANOTACIONES EN BD NUEVA: {len(books_new)}")
print("="*80)
print(books_new.head(20))
# Out:
# ================================================================================
# 📗 LIBROS CON ANOTACIONES EN BD NUEVA: 46
# ================================================================================
#                                                Título  \
# 0   ES MANIPULACIÓN Y NO LO SABES: DESACTIVA LAS T...
# 1                            The Happiness Hypothesis
# 2   Charisma on Command: Inspire, Impress, and Ene...
# 3                                        Fluir (Flow)
# 4                                Surrounded by Idiots
# 5   Cómo analizar a las personas y el lenguaje cor...
# 6                                              Models
# 7   Attached: Are you Anxious, Avoidant or Secure?...
# 8                                     El arte de amar
# 9   Autopsicología. Ejercicios y claves para una b...
# 10                             Las 5 trampas del amor
# 11  El sutil arte de que (casi todo) te importe un...
# 12                                            Mindset
# 13                       Los dones de la imperfección
# 14                               No More Mr. Nice Guy
# 15                                               Grit
# 16                             Cómo piensan los ricos
# 17                    El poder de confiar en ti mismo
# 18               Breaking the Habit of Being Yourself
# 19  Cómo invertir en Bolsa a largo plazo partiendo...
#
#                          Autor  Anotaciones
# 0             Claudia Nicolasa          443
# 1               Jonathan Haidt          260
# 2              Charlie Houpert          179
# 3      Mihály Csíkszentmihályi          178
# 4               Thomas Erikson          158
# 5                   Chase Hill          155
# 6                  Mark Manson          154
# 7                 Levine, Amir          150
# 8                  Erich Fromm          144
# 9     Alberto Bermejo Mercader          125
# 10                Iñaki Piñuel           92
# 11                 Mark Manson           80
# 12              Carol S. Dweck           79
# 13                 Brené Brown           76
# 14            Robert A. Glover           72
# 15            Angela Duckworth           70
# 16               Morgan Housel           67
# 17                 Brian Tracy           63
# 18                Joe Dispenza           61
# 19  Gregorio Hernández Jiménez           61

# %%
# Identificar libros que NECESITAN transferencia:
# Son aquellos que:
# 1. Tienen anotaciones en BD antigua
# 2. Existen en BD nueva (fueron redescargados)
# 3. Las anotaciones en BD antigua NO tienen capítulos (ContentID no mapeado)

print("="*80)
print("📋 ANALIZANDO LIBROS QUE NECESITAN TRANSFERENCIA")
print("="*80)

# Obtener libros que existen en ambas BDs
titles_old = set(books_old['Título'].tolist())
titles_new = set(books_new['Título'].tolist())

# Libros que están en ambas (redescargados)
books_in_both = titles_old & titles_new

print(f"\n📚 Libros en AMBAS bases de datos: {len(books_in_both)}")

if books_in_both:
    # Para cada libro en ambas BDs, verificar si tiene problemas de capítulos en BD antigua
    books_needing_transfer = []
    
    for book_title in books_in_both:
        # Obtener VolumeID del libro en BD antigua
        volume_query = """
            SELECT DISTINCT VolumeID
            FROM Bookmark b
            INNER JOIN content c ON b.VolumeID = c.ContentID
            WHERE c.Title = ?
            LIMIT 1
        """
        volume_result = db_old.get_query_df(volume_query, params=(book_title,))
        
        if len(volume_result) > 0:
            volume_id = volume_result['VolumeID'].iloc[0]
            
            # Verificar cuántas anotaciones tienen ContentID sin mapear a capítulo
            # (anotaciones donde ContentID = VolumeID o no existe en content)
            problem_query = """
                SELECT COUNT(*) as sin_capitulo
                FROM Bookmark b
                LEFT JOIN content c ON b.ContentID = c.ContentID
                WHERE b.VolumeID = ?
                AND b.Type IN ('highlight', 'note')
                AND (c.ContentID IS NULL OR c.ContentType != 9)
            """
            problem_result = db_old.get_query_df(problem_query, params=(volume_id,))
            
            total_query = """
                SELECT COUNT(*) as total
                FROM Bookmark b
                WHERE b.VolumeID = ?
                AND b.Type IN ('highlight', 'note')
            """
            total_result = db_old.get_query_df(total_query, params=(volume_id,))
            
            sin_capitulo = problem_result['sin_capitulo'].iloc[0]
            total = total_result['total'].iloc[0]
            
            # Si todas o la mayoría de anotaciones no tienen capítulo, necesita transferencia
            if sin_capitulo > 0 and sin_capitulo == total:
                books_needing_transfer.append({
                    'Título': book_title,
                    'Anotaciones': total,
                    'Sin_Capítulos': sin_capitulo
                })
    
    if books_needing_transfer:
        transfer_df = pd.DataFrame(books_needing_transfer).sort_values('Anotaciones', ascending=False)
        print(f"\n⚠️ LIBROS QUE NECESITAN TRANSFERENCIA: {len(books_needing_transfer)}")
        print("   (Libros redescargados donde las anotaciones antiguas NO tienen capítulos)")
        print("\n" + "="*80)
        print(transfer_df.to_string(index=False))
    else:
        print("\n✅ No hay libros que necesiten transferencia")
        print("   Todos los libros redescargados ya tienen anotaciones con capítulos correctos")
else:
    print("\n✅ No hay libros en común entre ambas bases de datos")
# Out:
# ================================================================================
# 📋 ANALIZANDO LIBROS QUE NECESITAN TRANSFERENCIA
# ================================================================================
#
# 📚 Libros en AMBAS bases de datos: 46
#
# ⚠️ LIBROS QUE NECESITAN TRANSFERENCIA: 17
#    (Libros redescargados donde las anotaciones antiguas NO tienen capítulos)
#
# ================================================================================
#                                                                         Título  Anotaciones  Sin_Capítulos
#                                                       The Happiness Hypothesis          260            260
#                                                           Surrounded by Idiots          158            158
#                                                                         Models          154            154
#                                                         Las 5 trampas del amor           92             92
#                                                                        Mindset           79             79
#                                                   Los dones de la imperfección           76             76
#                                                           No More Mr. Nice Guy           72             72
#                   TeorÃ­a del apego y psicoterapia: en busca de la base segura           57             57
#                                                      Surrounded by Narcissists           45             45
#                                                             Salir del infierno           41             41
#                                                            Minimalismo digital           26             26
#                                              Los seis pilares de la autoestima           14             14
# The Slight Edge: Turning Simple Disciplines into Massive Success and Happiness           14             14
#                                                              Psicología oscura           11             11
#                                               Manipulación y psicología oscura            7              7
#                                                         Una historia de España            3              3
#                                                                     Las madres            1              1
#
# ⚠️ LIBROS QUE NECESITAN TRANSFERENCIA: 17
#    (Libros redescargados donde las anotaciones antiguas NO tienen capítulos)
#
# ================================================================================
#                                                                         Título  Anotaciones  Sin_Capítulos
#                                                       The Happiness Hypothesis          260            260
#                                                           Surrounded by Idiots          158            158
#                                                                         Models          154            154
#                                                         Las 5 trampas del amor           92             92
#                                                                        Mindset           79             79
#                                                   Los dones de la imperfección           76             76
#                                                           No More Mr. Nice Guy           72             72
#                   TeorÃ­a del apego y psicoterapia: en busca de la base segura           57             57
#                                                      Surrounded by Narcissists           45             45
#                                                             Salir del infierno           41             41
#                                                            Minimalismo digital           26             26
#                                              Los seis pilares de la autoestima           14             14
# The Slight Edge: Turning Simple Disciplines into Massive Success and Happiness           14             14
#                                                              Psicología oscura           11             11
#                                               Manipulación y psicología oscura            7              7
#                                                         Una historia de España            3              3
#                                                                     Las madres            1              1

# %% [markdown]
# ### 💡 Explicación
#
# La celda anterior identifica libros que **necesitan transferencia de anotaciones** porque:
#
# 1. ✅ El libro existe en **ambas** bases de datos (fue redescargado)
# 2. ⚠️ Las anotaciones en la BD **antigua** NO tienen capítulos correctamente mapeados
# 3. ✅ En la BD **nueva** el libro tiene la estructura de capítulos correcta (96 capítulos, por ejemplo)
#
# **Por qué transferir:**
# - Las anotaciones antiguas están vinculadas al libro completo (sin capítulos específicos)
# - Al redescargarlo, el Kobo indexó correctamente los capítulos
# - Transferir las anotaciones permite mapearlas a los capítulos correctos usando la nueva estructura

# %% [markdown]
# ## 5. Verificación Post-Transferencia
#
# Después de ejecutar la transferencia, verifica que las anotaciones se copiaron correctamente.

# %%
# Verificar anotaciones de un libro específico en la BD nueva
# Cambia el patrón según el libro que transferiste

book_to_verify = '%historia de España%'

anotaciones_verificadas = db_new.get_query_df(f"""
    SELECT 
        l.Author as Autor,
        l.Title as Título, 
        COALESCE(c.Title, l.Title) as Capítulo,
        b.Text as Texto, 
        b.DateCreated as 'Fecha de creación'
    FROM Bookmark b 
    LEFT JOIN content c ON b.ContentID = c.ContentID
    INNER JOIN (
        SELECT DISTINCT b.VolumeID, c.Title, c.Attribution as Author
        FROM Bookmark b 
        INNER JOIN content c ON b.VolumeID = c.ContentID
    ) l ON b.VolumeID = l.VolumeID
    WHERE b.Type IN ("highlight", "note")
    AND l.Title LIKE '{book_to_verify}'
""")

print("="*80)
print(f"✅ ANOTACIONES TRANSFERIDAS: {len(anotaciones_verificadas)}")
print("="*80)
print(anotaciones_verificadas[['Capítulo', 'Texto', 'Fecha de creación']].to_string(index=False))
# Out:
# ================================================================================
# ✅ ANOTACIONES TRANSFERIDAS: 0
# ================================================================================
# Empty DataFrame
# Columns: [Capítulo, Texto, Fecha de creación]
# Index: []

# %% [markdown]
# ## 📝 Notas Importantes
#
# ### ✅ Qué hace el script:
# - Copia anotaciones (highlights y notas) de una BD a otra
# - Intenta mapear capítulos correctamente
# - Genera nuevos IDs únicos para evitar conflictos
# - Preserva fechas, textos y posiciones originales
# - NO duplica anotaciones que ya existen
#
# ### ⚠️ Limitaciones:
# - Busca libros por título exacto (debe coincidir)
# - Si un libro cambió de nombre al redescargarse, no lo encontrará
# - Anotaciones de formatos .kepub antiguos pueden no mapear capítulos correctamente
#
# ### 🔧 Alternativa: Script por línea de comandos
#
# También puedes usar el script desde terminal:
#
# ```bash
# # Simular
# python src/transfer_annotations.py --source data/KoboReader.sqlite --target data/KoboReader_5ene.sqlite --dry-run
#
# # Ejecutar
# python src/transfer_annotations.py --source data/KoboReader.sqlite --target data/KoboReader_5ene.sqlite
# ```
#
# Ver `README_TRANSFER.md` para más detalles.
